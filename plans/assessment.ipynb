# %% [markdown]
# # Holiday Manager
# ## Starting Files
# 1. JSON file, [holidays.json](https://stage3talent.brightspace.com/content/enforced/6899-G10-Data-Fundamentals-22-05/M07/assets/files/holidays.json?_&d2lSessionVal=Mf89mKiNBB928zdpy7uBH8zVp&ou=6899), seeds application with base of holidays
# 2. website: [Time and Date Holidays](timeanddate.com/holidays/us), web scrape holidays from there and preload, only pull concrete dates! 2 years previous, this year, and 2 years future
# 3. API: [Open Weather Map API](https://rapidapi.com/community/api/open-weather-map), show weather for the current period
# ## Requirements
# 1. Seed application with holidays from JSON file
# 2. Scrape and add holiday dates from past, future, and now from Time and Date holidays
# 3. Save all holidays in JSON, in the same format as the original holidays.json file
# 4. Show weather for the current time period

# %%
# all packages
import json
from dataclasses import dataclass, field
import requests
from bs4 import BeautifulSoup
from datetime import datetime
from datetime import date
from datetime import timedelta

currentYear = 2022
city = "New York City, USA"
weatherAPIKey = "55e9611df7msh8d9a1794a95dd96p1ff35bjsn79b2ab7fe896"

# %%
# all classes and member function definitions:
class Holiday:
      
    def __init__(self,name,date):
        #Your Code Here
        self.name = name
        if not isinstance(date, datetime):
            raise TypeError("date must be set to an datetime")
        self.date = date        
    
    def __str__(self):
        # String output
        # Holiday output when printed. Holiday Name (Date)
        outputstr = (f"{self.name} ({self.date.strftime('%Y-%m-%d')})")
        return outputstr

    def dictionaryOut(self):
        # to turn this element into a dictionary, date needs to be formatted as a string
        dictOut = {}
        dictOut['name'] = self.name
        dictOut['date'] = self.date.strftime('%Y-%m-%d')
        return dictOut

class HolidayList:
    def __init__(self):
        self.innerHolidays = []

    def __repr__(self):
        returnList = list(map(lambda b: b.__str__(), self.innerHolidays))
        returnStr = "\n".join(returnList)
        return returnStr

    def __str__(self):
        returnList = list(map(lambda b: b.__str__(), self.innerHolidays))
        returnStr = "\n".join(returnList)
        return returnStr
   
    def addHoliday(self,holidayObj):
        # Make sure holidayObj is an Holiday Object by checking the type
        if not isinstance(holidayObj, Holiday):
            raise TypeError("entry must be a Holiday type object")
        # Use innerHolidays.append(holidayObj) to add holiday
        self.innerHolidays.append(holidayObj)
        # print to the user that you added a holiday, would do this but the output would be really crowded...
        # print(f"{holidayObj.__str__()} has been added to the list!")
    
    def findHoliday(self, HolidayName, Date):
        # Find Holiday in innerHolidays
        if HolidayName == None and Date == None:
            results = "not found! no search terms defined!"
        elif Date == None:
            results = list(filter(lambda a: (a.name == HolidayName), self.innerHolidays))
            # print(f"Searching for holidays with name {HolidayName}: {len(results)} results")
        elif HolidayName == None:
            if not isinstance(Date, datetime):
                raise TypeError("date must be set to an datetime")
            results = list(filter(lambda a: (a.date == Date), self.innerHolidays))
            # print(f"Searching for holidays with date {Date}: {len(results)} results")
        else:
            if not isinstance(Date, datetime):
                raise TypeError("date must be set to an datetime")
            results = list(filter(lambda a: (a.name == HolidayName) and (a.date == Date), self.innerHolidays))
            # print(f"Searching for holidays with date {Date} and name {HolidayName}: {len(results)} results")
        # Return Holiday
        return results

    def removeHoliday(self, HolidayName, Date):
        if not isinstance(Date, datetime):
            raise TypeError("date must be set to an datetime")
        # Find Holiday in innerHolidays by searching the name and date combination.
        search = self.findHoliday(HolidayName, Date)
        holidayObject = Holiday(HolidayName,Date)
        if len(search) == 0: print(f"this holiday was not found on {Date}, please try again")
        else:
            print(f"{search[0].__str__()} has been found in the list!")
        # remove the Holiday from innerHolidays
            self.innerHolidays = list(filter(lambda a: (a.name != HolidayName or a.date != Date), self.innerHolidays))
        # inform user you deleted the holiday
            print("this holiday has been removed")
    
    def read_json(self,filelocation):
        # Read in things from json file location
        with open(filelocation) as file:
            holidaysJSON = json.load(file)['holidays']
        for i in range(0, len(holidaysJSON)):
            datetimeJSON= datetime.strptime(holidaysJSON[i]['date'], '%Y-%m-%d')
            singleHoliday = Holiday(holidaysJSON[i]['name'], datetimeJSON)
        # Use addHoliday function to add holidays to inner list.
            self.addHoliday(singleHoliday)

    def save_to_json(self,filelocation):
        # Write out json file to selected file.
        listHolidayDictionaries = list(map(lambda b: b.dictionaryOut(), self.innerHolidays))
        fullOutputDictionary = {'holidays': listHolidayDictionaries}
        JSONFormatting = json.dumps(fullOutputDictionary, indent=2)
        with open(filelocation, "w") as file:
            file.write(JSONFormatting)

    def scrapeHolidays(self):
        # Scrape Holidays from https://www.timeanddate.com/holidays/us/ 
        # Remember, 2 previous years, current year, and 2  years into the future. 
        # You can scrape multiple years by adding year to the timeanddate URL. 
        # For example https://www.timeanddate.com/holidays/us/2022
        global currentYear
        for year in range(currentYear-2,currentYear+3):
            url = "https://www.timeanddate.com/holidays/us/{}?hol=33554809".format(year)
            response = requests.get(url).text
            soup = BeautifulSoup(response,'html.parser')

            # isolate just the holiday table body
            holidayTable = soup.find('table',attrs={'id':'holidays-table'}).find('tbody')

            # get a list of all the specific holidays, taking out the first one because it is not a holiday lol
            perHoliday = holidayTable.find_all('tr', attrs={'class':'showrow'})
            count = 0 # to make sure all the holidays have been counted

            # going through all the holidays and getting the info
            for i in range(0,len(perHoliday)):
                # getting the date, converting to datetime using strings
                dateRaw = perHoliday[i].find('th', attrs={'class':'nw'}).text
                dateString = (f"{dateRaw} {year}")
                dateObject = datetime.strptime(dateString, "%b %d %Y")
                # getting the name
                name = perHoliday[i].find('a').text
                # search to see if it's already in the list
                # Check to see if name and date of holiday is in innerHolidays array
                search = self.findHoliday(name, dateObject)
                # Add non-duplicates to innerHolidays
                if len(search) == 0: 
                    self.addHoliday(Holiday(name, dateObject))
                    count += 1
                else:
                    # print(f"{name} on {dateString} is already in the list!")
                    pass
        
        # print(f"{count} holidays have been added for the year {year}.")
        # Handle any exceptions.     

    def numHolidays(self):
        # Return the total number of holidays in innerHolidays
        holidayNum = len(self.innerHolidays)
        return holidayNum

    def filter_holidays_by_week(self, year, week_number):
        # Use a Lambda function to filter by week number and save this as holidays, use the filter on innerHolidays
        # Week number is part of the the Datetime object
        # Cast filter results as list
        # filter by year
        yearFilter = list(filter(lambda a: (a.date.year == year), self.innerHolidays))
        # filter by week number
        weekFilter = list(filter(lambda a: (a.date.isocalendar()[1] == week_number), yearFilter))
        # return your holidays
        return weekFilter

    def displayHolidaysInWeek(self, holidayList):
        # Use your filter_holidays_by_week to get list of holidays within a week as a parameter
        # Output formated holidays in the week. 
        # * Remember to use the holiday __str__ method.
        # i don't really understand this function, just use print to display?
        for i in holidayList: print(i)

    def getWeather(self,year,weekNum):
        global city
        global weatherAPIKey
        global currentYear
        # Convert weekNum to range between two days
        today = datetime.today().replace(hour=0, minute=0, second=0, microsecond=0)
        monday = datetime.strptime(f'{year} {weekNum} 1', '%G %V %u')
        timeDiff = today - monday
        # Use Try / Except to catch problems
        # the API only queries for current weather data, the historical data is not working
        if timeDiff.days < -14 or timeDiff.days > 0:
            print("This weather API only works for the current day and a forecast of 2 weeks.")
            print("There is no weather data for this time period. Please try again!")
            print(f"Current year: {currentYear}, Current week: {today.isocalendar()[1]}")
            return
        # Query API for weather in that week range
        url = "https://community-open-weather-map.p.rapidapi.com/forecast/daily"
        querystring = {"q":city,"lat":"35","lon":"139","cnt":"16","units":"metric or imperial"}
        headers = {
            "X-RapidAPI-Key": weatherAPIKey,
            "X-RapidAPI-Host": "community-open-weather-map.p.rapidapi.com"
        }
        weather = requests.request("GET", url, headers=headers, params=querystring).text
        # Format weather information and return weather string.
        weatherDictRaw = json.loads(weather)["list"]
        weatherDictDate = {}
        for i in range(0,len(weatherDictRaw)):
            delta = timedelta(days=i)
            day = today + delta
            weatherDictDate[day] = weatherDictRaw[i]['weather'][0]['main']
        # filter and display output for just the days in that week
        weatherDictWeek = {}
        for i in range(1,8):
            weekday = datetime.strptime(f'{year} {weekNum} {i}', '%G %V %u')
            if weekday in list(weatherDictDate.keys()):
                weatherDictWeek[weekday] = weatherDictDate[weekday]
            else:
                weatherDictWeek[weekday] = "no data"
        return weatherDictWeek

    def viewCurrentWeek(self):
        # Use the Datetime Module to look up current week and year
        today = datetime.today().replace(hour=0, minute=0, second=0, microsecond=0)
        year = today.year
        weekN = today.isocalendar()[1]
        # Use your filter_holidays_by_week function to get the list of holidays for the current week/year
        weekHolidays = self.filter_holidays_by_week(year, weekN)
        # Use your displayHolidaysInWeek function to display the holidays in the week
        # Ask user if they want to get the weather
        while True:
            weatherDisplay = str(input("Would you like to see this week's weather? [y/n]: "))
            if weatherDisplay == "y" or weatherDisplay == "n":
                break
            else: print("invalid input!")
        # If yes, use your getWeather function and display results
        print("These are the holidays for this week:")
        if weatherDisplay == "y":
            weatherData = self.getWeather(year,weekN)
            # match each holiday date to weather date and print in an f string
            for event in weekHolidays:
                weatherEvent = weatherData[event.date]
                print(f"{event} - {weatherEvent}")
        elif weatherDisplay == "n":
            self.displayHolidaysInWeek(weekHolidays)

# %%
# testing datetime conversions, timedelta for getWeather functionality and error catching
year = 2022
weekNum = 1
monday = datetime.strptime(f'{year} {weekNum} 1', '%G %V %u')
sunday = datetime.strptime(f'{year} {weekNum} 7', '%G %V %u')
today = datetime.today()
timeDiff = today - monday
print(timeDiff)
def works(timeDiff):
    if timeDiff.days < -14 or timeDiff.days > 0:
        print("This weather API only works for the current day and a forecast of 2 weeks.")
        print("There is no weather data for this time period. Please try again!")
        return
    print("return does not work")
works(timeDiff)
# Out:
# 189 days, 1:26:44.665685
# This weather API only works for the current day and a forecast of 2 weeks.
# There is no weather data for this time period. Please try again!

# %%
# Testing weather data functionality, matching holidays to their weathers
z = a.getWeather(2022,28)
y = a.filter_holidays_by_week(2022,28)

today = datetime.today().replace(hour=0, minute=0, second=0, microsecond=0)
year = today.year
weekN = today.isocalendar()[1]
# Use your filter_holidays_by_week function to get the list of holidays for the current week/year
weekHolidays = y
# Use your displayHolidaysInWeek function to display the holidays in the week
# Ask user if they want to get the weather
while True:
    weatherDisplay = str(input("Would you like to see this week's weather? [y/n]: "))
    if weatherDisplay == "y" or weatherDisplay == "n":
        break
    else: print("invalid input!")
# If yes, use your getWeather function and display results
print("These are the holidays for this week:")
if weatherDisplay == "y":
    weatherData = z
    # match each holiday date to weather date and print in an f string
    for event in weekHolidays:
        weatherEvent = weatherData[event.date]
        print(f"{event} - {weatherEvent}")
elif weatherDisplay == "n":
    for i in y: print(i)
# Out:
# These are the holidays for this week:
# Bastille Day (2022-07-14) - Rain
# Rural Transit Day (2022-07-16) - Rain

# %%
# testing multiple year holiday removal
testNYE = HolidayList()
name = "New Year's Eve"
for year in range(2020, 2025):
    dateString = (f"Dec 31 {year}")
    dateObject = datetime.strptime(dateString, "%b %d %Y")
    holidayItem = Holiday(name, dateObject)
    testNYE.addHoliday(holidayItem)
name = "LAST DAY"
for year in range(2020, 2025):
    dateString = (f"Dec 31 {year}")
    dateObject = datetime.strptime(dateString, "%b %d %Y")
    holidayItem = Holiday(name, dateObject)
    testNYE.addHoliday(holidayItem)
name = "oh boy"
for year in range(2020, 2025):
    dateString = (f"Jan 1 {year}")
    dateObject = datetime.strptime(dateString, "%b %d %Y")
    holidayItem = Holiday(name, dateObject)
    testNYE.addHoliday(holidayItem)

print(testNYE)

# removing multiple holidays
dateObject1 = datetime.strptime("Dec 31 2020", "%b %d %Y")
testNYE.removeHoliday("New Year's Eve", dateObject1)

print(testNYE)
# Out:
# New Year's Eve (2020-12-31)
# New Year's Eve (2021-12-31)
# New Year's Eve (2022-12-31)
# New Year's Eve (2023-12-31)
# New Year's Eve (2024-12-31)
# LAST DAY (2020-12-31)
# LAST DAY (2021-12-31)
# LAST DAY (2022-12-31)
# LAST DAY (2023-12-31)
# LAST DAY (2024-12-31)
# oh boy (2020-01-01)
# oh boy (2021-01-01)
# oh boy (2022-01-01)
# oh boy (2023-01-01)
# oh boy (2024-01-01)
# New Year's Eve (2020-12-31) has been found in the list!
# this holiday has been removed
# New Year's Eve (2021-12-31)
# New Year's Eve (2022-12-31)
# New Year's Eve (2023-12-31)
# New Year's Eve (2024-12-31)
# LAST DAY (2020-12-31)
# LAST DAY (2021-12-31)
# LAST DAY (2022-12-31)
# LAST DAY (2023-12-31)
# LAST DAY (2024-12-31)
# oh boy (2020-01-01)
# oh boy (2021-01-01)
# oh boy (2022-01-01)
# oh boy (2023-01-01)
# oh boy (2024-01-01)

# %%
# testing member functions 
a = HolidayList()
a.read_json('test_holidayoutput.json')
a.scrapeHolidays()
a.numHolidays()
# Out:
# Margaret Thatcher Day (2021-01-10) has been added to the list!
# World Sketchnote Day (2021-01-11) has been added to the list!
# Zanzibar Revolution Day (2021-01-12) has been added to the list!
# National Rubber Ducky Day (2021-01-13) has been added to the list!
# Tamil Thai Pongdal Day (2021-01-14) has been added to the list!
# National Bagel Day (2021-01-15) has been added to the list!
# Signing of the Peace Accords (2021-01-16) has been added to the list!
# New Year's Day (2020-01-01) has been added to the list!
# Stephen Foster Memorial Day (2020-01-13) has been added to the list!
# Martin Luther King Jr. Day (2020-01-20) has been added to the list!
# Lunar New Year (2020-01-25) has been added to the list!
# Kansas Day (2020-01-29) has been added to the list!
# National Freedom Day (2020-02-01) has been added to the list!
# First Day of Black History Month (2020-02-01) has been added to the list!
# Groundhog Day (2020-02-02) has been added to the list!
# Super Bowl (2020-02-02) has been added to the list!
# National Girls and Women in Sports Day (2020-02-05) has been added to the list!
# National Wear Red Day (2020-02-07) has been added to the list!
# Valentine's Day (2020-02-14) has been added to the list!
# Presidents' Day (2020-02-17) has been added to the list!
# Shrove Tuesday/Mardi Gras (2020-02-25) has been added to the list!
# St. David's Day (2020-03-01) has been added to the list!
# First Day of Women's History Month (2020-03-01) has been added to the list!
# First Day of Irish American Heritage Month (2020-03-01) has been added to the list!
# Read Across America Day (2020-03-02) has been added to the list!
# Super Tuesday (2020-03-03) has been added to the list!
# Employee Appreciation Day (2020-03-06) has been added to the list!
# St. Patrick's Day (2020-03-17) has been added to the list!
# March Equinox (2020-03-19) has been added to the list!
# National Vietnam War Veterans Day (2020-03-29) has been added to the list!
# Doctors' Day (2020-03-30) has been added to the list!
# National Tartan Day (2020-04-06) has been added to the list!
# National Former Prisoner of War Recognition Day (2020-04-09) has been added to the list!
# Easter Sunday (2020-04-12) has been added to the list!
# Easter Monday (2020-04-13) has been added to the list!
# Thomas Jefferson's Birthday (2020-04-13) has been added to the list!
# National Library Workers' Day (2020-04-21) has been added to the list!
# Administrative Professionals Day (2020-04-22) has been added to the list!
# Take our Daughters and Sons to Work Day (2020-04-23) has been added to the list!
# Kentucky Oaks (2020-05-01) has been added to the list!
# Law Day (2020-05-01) has been added to the list!
# Loyalty Day (2020-05-01) has been added to the list!
# First Day of Military Appreciation Month (2020-05-01) has been added to the list!
# First Day of Asian Pacific American Heritage Month (2020-05-01) has been added to the list!
# First Day of Jewish American Heritage Month (2020-05-01) has been added to the list!
# National Explosive Ordnance Disposal (EOD) Day (2020-05-02) has been added to the list!
# Cinco de Mayo (2020-05-05) has been added to the list!
# National Teacher Appreciation Day (2020-05-05) has been added to the list!
# National Nurses Day (2020-05-06) has been added to the list!
# National Day of Prayer (2020-05-07) has been added to the list!
# Victory in Europe Day (2020-05-08) has been added to the list!
# Military Spouse Appreciation Day (2020-05-08) has been added to the list!
# Mother's Day (2020-05-10) has been added to the list!
# Peace Officers Memorial Day (2020-05-15) has been added to the list!
# National Defense Transportation Day (2020-05-15) has been added to the list!
# Armed Forces Day (2020-05-16) has been added to the list!
# Preakness Stakes (2020-05-16) has been added to the list!
# Emergency Medical Services for Children Day (2020-05-20) has been added to the list!
# National Maritime Day (2020-05-22) has been added to the list!
# Memorial Day (2020-05-25) has been added to the list!
# National Missing Children's Day (2020-05-25) has been added to the list!
# First Day of Pride Month (2020-06-01) has been added to the list!
# First Day of Caribbean-American Heritage Month (2020-06-01) has been added to the list!
# D-Day (2020-06-06) has been added to the list!
# Belmont Stakes (2020-06-06) has been added to the list!
# Loving Day (2020-06-12) has been added to the list!
# Army Birthday (2020-06-14) has been added to the list!
# Flag Day (2020-06-14) has been added to the list!
# Juneteenth (2020-06-19) has been added to the list!
# Juneteenth Independence Day (2020-06-19) has been added to the list!
# American Eagle Day (2020-06-20) has been added to the list!
# June Solstice (2020-06-20) has been added to the list!
# Father's Day (2020-06-21) has been added to the list!
# Independence Day (substitute) (2020-07-03) has been added to the list!
# Independence Day (2020-07-04) has been added to the list!
# Bastille Day (2020-07-14) has been added to the list!
# Tax Day (2020-07-15) has been added to the list!
# Rural Transit Day (2020-07-16) has been added to the list!
# Parents' Day (2020-07-26) has been added to the list!
# National Korean War Veterans Armistice Day (2020-07-27) has been added to the list!
# Coast Guard Birthday (2020-08-04) has been added to the list!
# Barack Obama Day (2020-08-04) has been added to the list!
# Purple Heart Day (2020-08-07) has been added to the list!
# National Senior Citizens Day (2020-08-16) has been added to the list!
# National Aviation Day (2020-08-19) has been added to the list!
# Women's Equality Day (2020-08-26) has been added to the list!
# Kentucky Derby (2020-09-05) has been added to the list!
# Labor Day (2020-09-07) has been added to the list!
# First Responders Day (2020-09-11) has been added to the list!
# Patriot Day (2020-09-11) has been added to the list!
# Carl Garner Federal Lands Cleanup Day (2020-09-12) has been added to the list!
# National Grandparents Day (2020-09-13) has been added to the list!
# First Day of National Hispanic Heritage Month (2020-09-15) has been added to the list!
# Constitution Day and Citizenship Day (2020-09-17) has been added to the list!
# Air Force Birthday (2020-09-18) has been added to the list!
# National POW/MIA Recognition Day (2020-09-18) has been added to the list!
# National CleanUp Day (2020-09-19) has been added to the list!
# September Equinox (2020-09-22) has been added to the list!
# National Public Lands Day (2020-09-26) has been added to the list!
# Gold Star Mother's Day (2020-09-27) has been added to the list!
# Child Health Day (2020-10-05) has been added to the list!
# German American Day (2020-10-06) has been added to the list!
# Leif Erikson Day (2020-10-09) has been added to the list!
# Chicago Marathon (2020-10-10) has been added to the list!
# Columbus Day (2020-10-12) has been added to the list!
# Navy Birthday (2020-10-13) has been added to the list!
# White Cane Safety Day (2020-10-15) has been added to the list!
# Boss's Day (2020-10-16) has been added to the list!
# Sweetest Day (2020-10-17) has been added to the list!
# Halloween (2020-10-31) has been added to the list!
# First Day of Native American Heritage Month (2020-11-01) has been added to the list!
# Election Day (General Election) (2020-11-03) has been added to the list!
# Marine Corps Birthday (2020-11-10) has been added to the list!
# Veterans Day (2020-11-11) has been added to the list!
# Thanksgiving Day (2020-11-26) has been added to the list!
# Black Friday (2020-11-27) has been added to the list!
# Native American Heritage Day (2020-11-27) has been added to the list!
# Cyber Monday (2020-11-30) has been added to the list!
# Giving Tuesday (2020-12-01) has been added to the list!
# St Nicholas Day (2020-12-06) has been added to the list!
# Pearl Harbor Remembrance Day (2020-12-07) has been added to the list!
# National Guard Birthday (2020-12-13) has been added to the list!
# Bill of Rights Day (2020-12-15) has been added to the list!
# Pan American Aviation Day (2020-12-17) has been added to the list!
# Wright Brothers Day (2020-12-17) has been added to the list!
# December Solstice (2020-12-21) has been added to the list!
# Christmas Eve (2020-12-24) has been added to the list!
# Christmas Eve on Dec 24 2020 is already in the list!
# Christmas Day (2020-12-25) has been added to the list!
# Kwanzaa (first day) (2020-12-26) has been added to the list!
# New Year's Eve (2020-12-31) has been added to the list!
# New Year's Day (2021-01-01) has been added to the list!
# Stephen Foster Memorial Day (2021-01-13) has been added to the list!
# Martin Luther King Jr. Day (2021-01-18) has been added to the list!
# Inauguration Day (2021-01-20) has been added to the list!
# Kansas Day (2021-01-29) has been added to the list!
# National Freedom Day (2021-02-01) has been added to the list!
# First Day of Black History Month (2021-02-01) has been added to the list!
# Groundhog Day (2021-02-02) has been added to the list!
# National Girls and Women in Sports Day (2021-02-03) has been added to the list!
# National Wear Red Day (2021-02-05) has been added to the list!
# Super Bowl (2021-02-07) has been added to the list!
# Lunar New Year (2021-02-12) has been added to the list!
# Valentine's Day (2021-02-14) has been added to the list!
# Presidents' Day (2021-02-15) has been added to the list!
# Shrove Tuesday/Mardi Gras (2021-02-16) has been added to the list!
# St. David's Day (2021-03-01) has been added to the list!
# First Day of Women's History Month (2021-03-01) has been added to the list!
# First Day of Irish American Heritage Month (2021-03-01) has been added to the list!
# Read Across America Day (2021-03-02) has been added to the list!
# Employee Appreciation Day (2021-03-05) has been added to the list!
# St. Patrick's Day (2021-03-17) has been added to the list!
# March Equinox (2021-03-20) has been added to the list!
# National Vietnam War Veterans Day (2021-03-29) has been added to the list!
# Doctors' Day (2021-03-30) has been added to the list!
# Easter Sunday (2021-04-04) has been added to the list!
# Easter Monday (2021-04-05) has been added to the list!
# National Tartan Day (2021-04-06) has been added to the list!
# National Library Workers' Day (2021-04-06) has been added to the list!
# Thomas Jefferson's Birthday (2021-04-13) has been added to the list!
# Administrative Professionals Day (2021-04-21) has been added to the list!
# Take our Daughters and Sons to Work Day (2021-04-22) has been added to the list!
# Kentucky Oaks (2021-04-30) has been added to the list!
# Kentucky Derby (2021-05-01) has been added to the list!
# Law Day (2021-05-01) has been added to the list!
# Loyalty Day (2021-05-01) has been added to the list!
# National Explosive Ordnance Disposal (EOD) Day (2021-05-01) has been added to the list!
# First Day of Military Appreciation Month (2021-05-01) has been added to the list!
# First Day of Asian Pacific American Heritage Month (2021-05-01) has been added to the list!
# First Day of Jewish American Heritage Month (2021-05-01) has been added to the list!
# National Teacher Appreciation Day (2021-05-04) has been added to the list!
# Cinco de Mayo (2021-05-05) has been added to the list!
# National Nurses Day (2021-05-06) has been added to the list!
# National Day of Prayer (2021-05-06) has been added to the list!
# Military Spouse Appreciation Day (2021-05-07) has been added to the list!
# Victory in Europe Day (2021-05-08) has been added to the list!
# Mother's Day (2021-05-09) has been added to the list!
# Peace Officers Memorial Day (2021-05-15) has been added to the list!
# Armed Forces Day (2021-05-15) has been added to the list!
# Preakness Stakes (2021-05-15) has been added to the list!
# Tax Day (2021-05-17) has been added to the list!
# Emergency Medical Services for Children Day (2021-05-19) has been added to the list!
# National Defense Transportation Day (2021-05-21) has been added to the list!
# National Maritime Day (2021-05-22) has been added to the list!
# National Missing Children's Day (2021-05-25) has been added to the list!
# Memorial Day (2021-05-31) has been added to the list!
# First Day of Pride Month (2021-06-01) has been added to the list!
# First Day of Caribbean-American Heritage Month (2021-06-01) has been added to the list!
# Belmont Stakes (2021-06-05) has been added to the list!
# D-Day (2021-06-06) has been added to the list!
# Loving Day (2021-06-12) has been added to the list!
# Army Birthday (2021-06-14) has been added to the list!
# Flag Day (2021-06-14) has been added to the list!
# Juneteenth (substitute) (2021-06-18) has been added to the list!
# Juneteenth (2021-06-19) has been added to the list!
# Father's Day (2021-06-20) has been added to the list!
# American Eagle Day (2021-06-20) has been added to the list!
# June Solstice (2021-06-20) has been added to the list!
# Independence Day (2021-07-04) has been added to the list!
# Independence Day (substitute) (2021-07-05) has been added to the list!
# Bastille Day (2021-07-14) has been added to the list!
# Rural Transit Day (2021-07-16) has been added to the list!
# Parents' Day (2021-07-25) has been added to the list!
# National Korean War Veterans Armistice Day (2021-07-27) has been added to the list!
# Coast Guard Birthday (2021-08-04) has been added to the list!
# Barack Obama Day (2021-08-04) has been added to the list!
# Purple Heart Day (2021-08-07) has been added to the list!
# National Senior Citizens Day (2021-08-15) has been added to the list!
# National Aviation Day (2021-08-19) has been added to the list!
# Women's Equality Day (2021-08-26) has been added to the list!
# Labor Day (2021-09-06) has been added to the list!
# First Responders Day (2021-09-11) has been added to the list!
# Patriot Day (2021-09-11) has been added to the list!
# Carl Garner Federal Lands Cleanup Day (2021-09-11) has been added to the list!
# National Grandparents Day (2021-09-12) has been added to the list!
# First Day of National Hispanic Heritage Month (2021-09-15) has been added to the list!
# Constitution Day and Citizenship Day (2021-09-17) has been added to the list!
# National POW/MIA Recognition Day (2021-09-17) has been added to the list!
# Air Force Birthday (2021-09-18) has been added to the list!
# National CleanUp Day (2021-09-18) has been added to the list!
# September Equinox (2021-09-22) has been added to the list!
# National Public Lands Day (2021-09-25) has been added to the list!
# Gold Star Mother's Day (2021-09-26) has been added to the list!
# Child Health Day (2021-10-04) has been added to the list!
# German American Day (2021-10-06) has been added to the list!
# Leif Erikson Day (2021-10-09) has been added to the list!
# Chicago Marathon (2021-10-10) has been added to the list!
# Columbus Day (2021-10-11) has been added to the list!
# Indigenous People's Day (2021-10-11) has been added to the list!
# Boston Marathon (2021-10-11) has been added to the list!
# Navy Birthday (2021-10-13) has been added to the list!
# White Cane Safety Day (2021-10-15) has been added to the list!
# Boss's Day (2021-10-15) has been added to the list!
# Sweetest Day (2021-10-16) has been added to the list!
# Halloween (2021-10-31) has been added to the list!
# First Day of Native American Heritage Month (2021-11-01) has been added to the list!
# Election Day (2021-11-02) has been added to the list!
# New York City Marathon (2021-11-07) has been added to the list!
# Marine Corps Birthday (2021-11-10) has been added to the list!
# Veterans Day (2021-11-11) has been added to the list!
# Thanksgiving Day (2021-11-25) has been added to the list!
# Black Friday (2021-11-26) has been added to the list!
# Native American Heritage Day (2021-11-26) has been added to the list!
# Cyber Monday (2021-11-29) has been added to the list!
# Giving Tuesday (2021-11-30) has been added to the list!
# St Nicholas Day (2021-12-06) has been added to the list!
# Pearl Harbor Remembrance Day (2021-12-07) has been added to the list!
# National Guard Birthday (2021-12-13) has been added to the list!
# Bill of Rights Day (2021-12-15) has been added to the list!
# Pan American Aviation Day (2021-12-17) has been added to the list!
# Wright Brothers Day (2021-12-17) has been added to the list!
# December Solstice (2021-12-21) has been added to the list!
# Christmas Day (substitute) (2021-12-24) has been added to the list!
# Christmas Eve (2021-12-24) has been added to the list!
# Christmas Day (2021-12-25) has been added to the list!
# Kwanzaa (first day) (2021-12-26) has been added to the list!
# New Year's Day (substitute) (2021-12-31) has been added to the list!
# New Year's Eve (2021-12-31) has been added to the list!
# New Year's Day (2022-01-01) has been added to the list!
# Stephen Foster Memorial Day (2022-01-13) has been added to the list!
# Martin Luther King Jr. Day (2022-01-17) has been added to the list!
# Kansas Day (2022-01-29) has been added to the list!
# National Freedom Day (2022-02-01) has been added to the list!
# Lunar New Year (2022-02-01) has been added to the list!
# First Day of Black History Month (2022-02-01) has been added to the list!
# Groundhog Day (2022-02-02) has been added to the list!
# National Girls and Women in Sports Day (2022-02-02) has been added to the list!
# National Wear Red Day (2022-02-04) has been added to the list!
# Super Bowl (2022-02-13) has been added to the list!
# Valentine's Day (2022-02-14) has been added to the list!
# Presidents' Day (2022-02-21) has been added to the list!
# Shrove Tuesday/Mardi Gras (2022-03-01) has been added to the list!
# St. David's Day (2022-03-01) has been added to the list!
# First Day of Women's History Month (2022-03-01) has been added to the list!
# First Day of Irish American Heritage Month (2022-03-01) has been added to the list!
# Read Across America Day (2022-03-02) has been added to the list!
# Employee Appreciation Day (2022-03-04) has been added to the list!
# St. Patrick's Day (2022-03-17) has been added to the list!
# March Equinox (2022-03-20) has been added to the list!
# National Vietnam War Veterans Day (2022-03-29) has been added to the list!
# Doctors' Day (2022-03-30) has been added to the list!
# National Tartan Day (2022-04-06) has been added to the list!
# National Library Workers' Day (2022-04-12) has been added to the list!
# Thomas Jefferson's Birthday (2022-04-13) has been added to the list!
# Easter Sunday (2022-04-17) has been added to the list!
# Easter Monday (2022-04-18) has been added to the list!
# Tax Day (2022-04-18) has been added to the list!
# Boston Marathon (2022-04-18) has been added to the list!
# Administrative Professionals Day (2022-04-27) has been added to the list!
# Take our Daughters and Sons to Work Day (2022-04-28) has been added to the list!
# Law Day (2022-05-01) has been added to the list!
# Loyalty Day (2022-05-01) has been added to the list!
# First Day of Military Appreciation Month (2022-05-01) has been added to the list!
# First Day of Asian Pacific American Heritage Month (2022-05-01) has been added to the list!
# First Day of Jewish American Heritage Month (2022-05-01) has been added to the list!
# National Teacher Appreciation Day (2022-05-03) has been added to the list!
# Cinco de Mayo (2022-05-05) has been added to the list!
# National Day of Prayer (2022-05-05) has been added to the list!
# Kentucky Oaks (2022-05-06) has been added to the list!
# National Nurses Day (2022-05-06) has been added to the list!
# Military Spouse Appreciation Day (2022-05-06) has been added to the list!
# Kentucky Derby (2022-05-07) has been added to the list!
# National Explosive Ordnance Disposal (EOD) Day (2022-05-07) has been added to the list!
# Mother's Day (2022-05-08) has been added to the list!
# Victory in Europe Day (2022-05-08) has been added to the list!
# Peace Officers Memorial Day (2022-05-15) has been added to the list!
# National Defense Transportation Day (2022-05-20) has been added to the list!
# Armed Forces Day (2022-05-21) has been added to the list!
# Preakness Stakes (2022-05-21) has been added to the list!
# National Maritime Day (2022-05-22) has been added to the list!
# Emergency Medical Services for Children Day (2022-05-25) has been added to the list!
# National Missing Children's Day (2022-05-25) has been added to the list!
# Memorial Day (2022-05-30) has been added to the list!
# First Day of Pride Month (2022-06-01) has been added to the list!
# First Day of Caribbean-American Heritage Month (2022-06-01) has been added to the list!
# D-Day (2022-06-06) has been added to the list!
# Belmont Stakes (2022-06-11) has been added to the list!
# Loving Day (2022-06-12) has been added to the list!
# Army Birthday (2022-06-14) has been added to the list!
# Flag Day (2022-06-14) has been added to the list!
# Father's Day (2022-06-19) has been added to the list!
# Juneteenth (2022-06-19) has been added to the list!
# Juneteenth Independence Day (2022-06-19) has been added to the list!
# Juneteenth (substitute) (2022-06-20) has been added to the list!
# American Eagle Day (2022-06-20) has been added to the list!
# June Solstice (2022-06-21) has been added to the list!
# Independence Day (2022-07-04) has been added to the list!
# Bastille Day (2022-07-14) has been added to the list!
# Rural Transit Day (2022-07-16) has been added to the list!
# Parents' Day (2022-07-24) has been added to the list!
# National Korean War Veterans Armistice Day (2022-07-27) has been added to the list!
# Coast Guard Birthday (2022-08-04) has been added to the list!
# Barack Obama Day (2022-08-04) has been added to the list!
# Purple Heart Day (2022-08-07) has been added to the list!
# National Aviation Day (2022-08-19) has been added to the list!
# National Senior Citizens Day (2022-08-21) has been added to the list!
# Women's Equality Day (2022-08-26) has been added to the list!
# Labor Day (2022-09-05) has been added to the list!
# Carl Garner Federal Lands Cleanup Day (2022-09-10) has been added to the list!
# First Responders Day (2022-09-11) has been added to the list!
# Patriot Day (2022-09-11) has been added to the list!
# National Grandparents Day (2022-09-11) has been added to the list!
# First Day of National Hispanic Heritage Month (2022-09-15) has been added to the list!
# Constitution Day and Citizenship Day observed (2022-09-16) has been added to the list!
# National POW/MIA Recognition Day (2022-09-16) has been added to the list!
# Constitution Day and Citizenship Day (2022-09-17) has been added to the list!
# National CleanUp Day (2022-09-17) has been added to the list!
# Air Force Birthday (2022-09-18) has been added to the list!
# September Equinox (2022-09-22) has been added to the list!
# National Public Lands Day (2022-09-24) has been added to the list!
# Gold Star Mother's Day (2022-09-25) has been added to the list!
# Child Health Day (2022-10-03) has been added to the list!
# German American Day (2022-10-06) has been added to the list!
# Leif Erikson Day (2022-10-09) has been added to the list!
# Chicago Marathon (2022-10-09) has been added to the list!
# Columbus Day (2022-10-10) has been added to the list!
# Navy Birthday (2022-10-13) has been added to the list!
# White Cane Safety Day (2022-10-15) has been added to the list!
# Sweetest Day (2022-10-15) has been added to the list!
# Boss's Day (2022-10-17) has been added to the list!
# Halloween (2022-10-31) has been added to the list!
# First Day of Native American Heritage Month (2022-11-01) has been added to the list!
# New York City Marathon (2022-11-06) has been added to the list!
# Election Day (2022-11-08) has been added to the list!
# Marine Corps Birthday (2022-11-10) has been added to the list!
# Veterans Day (2022-11-11) has been added to the list!
# Thanksgiving Day (2022-11-24) has been added to the list!
# Black Friday (2022-11-25) has been added to the list!
# Native American Heritage Day (2022-11-25) has been added to the list!
# Cyber Monday (2022-11-28) has been added to the list!
# Giving Tuesday (2022-11-29) has been added to the list!
# St Nicholas Day (2022-12-06) has been added to the list!
# Pearl Harbor Remembrance Day (2022-12-07) has been added to the list!
# National Guard Birthday (2022-12-13) has been added to the list!
# Bill of Rights Day (2022-12-15) has been added to the list!
# Pan American Aviation Day (2022-12-17) has been added to the list!
# Wright Brothers Day (2022-12-17) has been added to the list!
# December Solstice (2022-12-21) has been added to the list!
# Christmas Eve (2022-12-24) has been added to the list!
# Christmas Day (2022-12-25) has been added to the list!
# Kwanzaa (first day) (2022-12-26) has been added to the list!
# Christmas Day (substitute) (2022-12-26) has been added to the list!
# New Year's Eve (2022-12-31) has been added to the list!
# New Year's Day (2023-01-01) has been added to the list!
# New Year's Day (substitute) (2023-01-02) has been added to the list!
# Stephen Foster Memorial Day (2023-01-13) has been added to the list!
# Martin Luther King Jr. Day (2023-01-16) has been added to the list!
# Lunar New Year (2023-01-22) has been added to the list!
# Kansas Day (2023-01-29) has been added to the list!
# National Freedom Day (2023-02-01) has been added to the list!
# National Girls and Women in Sports Day (2023-02-01) has been added to the list!
# First Day of Black History Month (2023-02-01) has been added to the list!
# Groundhog Day (2023-02-02) has been added to the list!
# National Wear Red Day (2023-02-03) has been added to the list!
# Super Bowl (2023-02-12) has been added to the list!
# Valentine's Day (2023-02-14) has been added to the list!
# Presidents' Day (2023-02-20) has been added to the list!
# Shrove Tuesday/Mardi Gras (2023-02-21) has been added to the list!
# St. David's Day (2023-03-01) has been added to the list!
# First Day of Women's History Month (2023-03-01) has been added to the list!
# First Day of Irish American Heritage Month (2023-03-01) has been added to the list!
# Read Across America Day (2023-03-02) has been added to the list!
# Employee Appreciation Day (2023-03-03) has been added to the list!
# St. Patrick's Day (2023-03-17) has been added to the list!
# March Equinox (2023-03-20) has been added to the list!
# National Vietnam War Veterans Day (2023-03-29) has been added to the list!
# Doctors' Day (2023-03-30) has been added to the list!
# National Tartan Day (2023-04-06) has been added to the list!
# Easter Sunday (2023-04-09) has been added to the list!
# Easter Monday (2023-04-10) has been added to the list!
# Thomas Jefferson's Birthday (2023-04-13) has been added to the list!
# Boston Marathon (2023-04-17) has been added to the list!
# Tax Day (2023-04-18) has been added to the list!
# National Library Workers' Day (2023-04-25) has been added to the list!
# Administrative Professionals Day (2023-04-26) has been added to the list!
# Take our Daughters and Sons to Work Day (2023-04-27) has been added to the list!
# Law Day (2023-05-01) has been added to the list!
# Loyalty Day (2023-05-01) has been added to the list!
# First Day of Military Appreciation Month (2023-05-01) has been added to the list!
# First Day of Asian Pacific American Heritage Month (2023-05-01) has been added to the list!
# First Day of Jewish American Heritage Month (2023-05-01) has been added to the list!
# National Teacher Appreciation Day (2023-05-02) has been added to the list!
# National Day of Prayer (2023-05-04) has been added to the list!
# Cinco de Mayo (2023-05-05) has been added to the list!
# Kentucky Oaks (2023-05-05) has been added to the list!
# Kentucky Derby (2023-05-06) has been added to the list!
# National Nurses Day (2023-05-06) has been added to the list!
# National Explosive Ordnance Disposal (EOD) Day (2023-05-06) has been added to the list!
# Victory in Europe Day (2023-05-08) has been added to the list!
# Military Spouse Appreciation Day (2023-05-12) has been added to the list!
# Mother's Day (2023-05-14) has been added to the list!
# Peace Officers Memorial Day (2023-05-15) has been added to the list!
# National Defense Transportation Day (2023-05-19) has been added to the list!
# Armed Forces Day (2023-05-20) has been added to the list!
# Preakness Stakes (2023-05-20) has been added to the list!
# National Maritime Day (2023-05-22) has been added to the list!
# Emergency Medical Services for Children Day (2023-05-24) has been added to the list!
# National Missing Children's Day (2023-05-25) has been added to the list!
# Memorial Day (2023-05-29) has been added to the list!
# First Day of Pride Month (2023-06-01) has been added to the list!
# First Day of Caribbean-American Heritage Month (2023-06-01) has been added to the list!
# D-Day (2023-06-06) has been added to the list!
# Belmont Stakes (2023-06-10) has been added to the list!
# Loving Day (2023-06-12) has been added to the list!
# Army Birthday (2023-06-14) has been added to the list!
# Flag Day (2023-06-14) has been added to the list!
# Father's Day (2023-06-18) has been added to the list!
# Juneteenth (2023-06-19) has been added to the list!
# Juneteenth Independence Day (2023-06-19) has been added to the list!
# American Eagle Day (2023-06-20) has been added to the list!
# June Solstice (2023-06-21) has been added to the list!
# Independence Day (2023-07-04) has been added to the list!
# Bastille Day (2023-07-14) has been added to the list!
# Rural Transit Day (2023-07-16) has been added to the list!
# Parents' Day (2023-07-23) has been added to the list!
# National Korean War Veterans Armistice Day (2023-07-27) has been added to the list!
# Coast Guard Birthday (2023-08-04) has been added to the list!
# Barack Obama Day (2023-08-04) has been added to the list!
# Purple Heart Day (2023-08-07) has been added to the list!
# National Aviation Day (2023-08-19) has been added to the list!
# National Senior Citizens Day (2023-08-20) has been added to the list!
# Women's Equality Day (2023-08-26) has been added to the list!
# Labor Day (2023-09-04) has been added to the list!
# Carl Garner Federal Lands Cleanup Day (2023-09-09) has been added to the list!
# National Grandparents Day (2023-09-10) has been added to the list!
# First Responders Day (2023-09-11) has been added to the list!
# Patriot Day (2023-09-11) has been added to the list!
# First Day of National Hispanic Heritage Month (2023-09-15) has been added to the list!
# National POW/MIA Recognition Day (2023-09-15) has been added to the list!
# Constitution Day and Citizenship Day (2023-09-17) has been added to the list!
# Air Force Birthday (2023-09-18) has been added to the list!
# Constitution Day and Citizenship Day observed (2023-09-18) has been added to the list!
# National Public Lands Day (2023-09-23) has been added to the list!
# September Equinox (2023-09-23) has been added to the list!
# Gold Star Mother's Day (2023-09-24) has been added to the list!
# Child Health Day (2023-10-02) has been added to the list!
# German American Day (2023-10-06) has been added to the list!
# Chicago Marathon (Tentative Date) (2023-10-08) has been added to the list!
# Leif Erikson Day (2023-10-09) has been added to the list!
# Columbus Day (2023-10-09) has been added to the list!
# Navy Birthday (2023-10-13) has been added to the list!
# White Cane Safety Day (2023-10-15) has been added to the list!
# Boss's Day (2023-10-16) has been added to the list!
# Sweetest Day (2023-10-21) has been added to the list!
# Halloween (2023-10-31) has been added to the list!
# First Day of Native American Heritage Month (2023-11-01) has been added to the list!
# New York City Marathon (2023-11-05) has been added to the list!
# Election Day (2023-11-07) has been added to the list!
# Marine Corps Birthday (2023-11-10) has been added to the list!
# Veterans Day (substitute) (2023-11-10) has been added to the list!
# Veterans Day (2023-11-11) has been added to the list!
# Thanksgiving Day (2023-11-23) has been added to the list!
# Black Friday (2023-11-24) has been added to the list!
# Native American Heritage Day (2023-11-24) has been added to the list!
# Cyber Monday (2023-11-27) has been added to the list!
# Giving Tuesday (2023-11-28) has been added to the list!
# St Nicholas Day (2023-12-06) has been added to the list!
# Pearl Harbor Remembrance Day (2023-12-07) has been added to the list!
# National Guard Birthday (2023-12-13) has been added to the list!
# Bill of Rights Day (2023-12-15) has been added to the list!
# Pan American Aviation Day (2023-12-17) has been added to the list!
# Wright Brothers Day (2023-12-17) has been added to the list!
# December Solstice (2023-12-21) has been added to the list!
# Christmas Eve (2023-12-24) has been added to the list!
# Christmas Day (2023-12-25) has been added to the list!
# Kwanzaa (first day) (2023-12-26) has been added to the list!
# New Year's Eve (2023-12-31) has been added to the list!
# New Year's Day (2024-01-01) has been added to the list!
# Stephen Foster Memorial Day (2024-01-13) has been added to the list!
# Martin Luther King Jr. Day (2024-01-15) has been added to the list!
# Kansas Day (2024-01-29) has been added to the list!
# National Freedom Day (2024-02-01) has been added to the list!
# First Day of Black History Month (2024-02-01) has been added to the list!
# Groundhog Day (2024-02-02) has been added to the list!
# National Wear Red Day (2024-02-02) has been added to the list!
# National Girls and Women in Sports Day (2024-02-07) has been added to the list!
# Lunar New Year (2024-02-10) has been added to the list!
# Super Bowl (2024-02-11) has been added to the list!
# Shrove Tuesday/Mardi Gras (2024-02-13) has been added to the list!
# Valentine's Day (2024-02-14) has been added to the list!
# Presidents' Day (2024-02-19) has been added to the list!
# St. David's Day (2024-03-01) has been added to the list!
# Read Across America Day (2024-03-01) has been added to the list!
# Employee Appreciation Day (2024-03-01) has been added to the list!
# First Day of Women's History Month (2024-03-01) has been added to the list!
# First Day of Irish American Heritage Month (2024-03-01) has been added to the list!
# St. Patrick's Day (2024-03-17) has been added to the list!
# March Equinox (2024-03-19) has been added to the list!
# National Vietnam War Veterans Day (2024-03-29) has been added to the list!
# Doctors' Day (2024-03-30) has been added to the list!
# Easter Sunday (2024-03-31) has been added to the list!
# Easter Monday (2024-04-01) has been added to the list!
# National Tartan Day (2024-04-06) has been added to the list!
# National Library Workers' Day (2024-04-09) has been added to the list!
# Thomas Jefferson's Birthday (2024-04-13) has been added to the list!
# Tax Day (2024-04-15) has been added to the list!
# Boston Marathon (2024-04-15) has been added to the list!
# Administrative Professionals Day (2024-04-24) has been added to the list!
# Take our Daughters and Sons to Work Day (2024-04-25) has been added to the list!
# Law Day (2024-05-01) has been added to the list!
# Loyalty Day (2024-05-01) has been added to the list!
# First Day of Military Appreciation Month (2024-05-01) has been added to the list!
# First Day of Asian Pacific American Heritage Month (2024-05-01) has been added to the list!
# First Day of Jewish American Heritage Month (2024-05-01) has been added to the list!
# National Day of Prayer (2024-05-02) has been added to the list!
# Kentucky Oaks (2024-05-03) has been added to the list!
# Kentucky Derby (2024-05-04) has been added to the list!
# National Explosive Ordnance Disposal (EOD) Day (2024-05-04) has been added to the list!
# Cinco de Mayo (2024-05-05) has been added to the list!
# National Nurses Day (2024-05-06) has been added to the list!
# National Teacher Appreciation Day (2024-05-07) has been added to the list!
# Victory in Europe Day (2024-05-08) has been added to the list!
# Military Spouse Appreciation Day (2024-05-10) has been added to the list!
# Mother's Day (2024-05-12) has been added to the list!
# Peace Officers Memorial Day (2024-05-15) has been added to the list!
# National Defense Transportation Day (2024-05-17) has been added to the list!
# Armed Forces Day (2024-05-18) has been added to the list!
# Preakness Stakes (2024-05-18) has been added to the list!
# Emergency Medical Services for Children Day (2024-05-22) has been added to the list!
# National Maritime Day (2024-05-22) has been added to the list!
# National Missing Children's Day (2024-05-25) has been added to the list!
# Memorial Day (2024-05-27) has been added to the list!
# First Day of Pride Month (2024-06-01) has been added to the list!
# First Day of Caribbean-American Heritage Month (2024-06-01) has been added to the list!
# D-Day (2024-06-06) has been added to the list!
# Belmont Stakes (2024-06-08) has been added to the list!
# Loving Day (2024-06-12) has been added to the list!
# Army Birthday (2024-06-14) has been added to the list!
# Flag Day (2024-06-14) has been added to the list!
# Father's Day (2024-06-16) has been added to the list!
# Juneteenth (2024-06-19) has been added to the list!
# Juneteenth Independence Day (2024-06-19) has been added to the list!
# American Eagle Day (2024-06-20) has been added to the list!
# June Solstice (2024-06-20) has been added to the list!
# Independence Day (2024-07-04) has been added to the list!
# Bastille Day (2024-07-14) has been added to the list!
# Rural Transit Day (2024-07-16) has been added to the list!
# National Korean War Veterans Armistice Day (2024-07-27) has been added to the list!
# Parents' Day (2024-07-28) has been added to the list!
# Coast Guard Birthday (2024-08-04) has been added to the list!
# Barack Obama Day (2024-08-04) has been added to the list!
# Purple Heart Day (2024-08-07) has been added to the list!
# National Senior Citizens Day (2024-08-18) has been added to the list!
# National Aviation Day (2024-08-19) has been added to the list!
# Women's Equality Day (2024-08-26) has been added to the list!
# Labor Day (2024-09-02) has been added to the list!
# Carl Garner Federal Lands Cleanup Day (2024-09-07) has been added to the list!
# National Grandparents Day (2024-09-08) has been added to the list!
# First Responders Day (2024-09-11) has been added to the list!
# Patriot Day (2024-09-11) has been added to the list!
# First Day of National Hispanic Heritage Month (2024-09-15) has been added to the list!
# Constitution Day and Citizenship Day (2024-09-17) has been added to the list!
# Air Force Birthday (2024-09-18) has been added to the list!
# National POW/MIA Recognition Day (2024-09-20) has been added to the list!
# September Equinox (2024-09-22) has been added to the list!
# National Public Lands Day (2024-09-28) has been added to the list!
# Gold Star Mother's Day (2024-09-29) has been added to the list!
# German American Day (2024-10-06) has been added to the list!
# Child Health Day (2024-10-07) has been added to the list!
# Leif Erikson Day (2024-10-09) has been added to the list!
# Navy Birthday (2024-10-13) has been added to the list!
# Chicago Marathon (Tentative Date) (2024-10-13) has been added to the list!
# Columbus Day (2024-10-14) has been added to the list!
# White Cane Safety Day (2024-10-15) has been added to the list!
# Boss's Day (2024-10-16) has been added to the list!
# Sweetest Day (2024-10-19) has been added to the list!
# Halloween (2024-10-31) has been added to the list!
# First Day of Native American Heritage Month (2024-11-01) has been added to the list!
# New York City Marathon (2024-11-03) has been added to the list!
# Election Day (General Election) (2024-11-05) has been added to the list!
# Marine Corps Birthday (2024-11-10) has been added to the list!
# Veterans Day (2024-11-11) has been added to the list!
# Thanksgiving Day (2024-11-28) has been added to the list!
# Black Friday (2024-11-29) has been added to the list!
# Native American Heritage Day (2024-11-29) has been added to the list!
# Cyber Monday (2024-12-02) has been added to the list!
# Giving Tuesday (2024-12-03) has been added to the list!
# St Nicholas Day (2024-12-06) has been added to the list!
# Pearl Harbor Remembrance Day (2024-12-07) has been added to the list!
# National Guard Birthday (2024-12-13) has been added to the list!
# Bill of Rights Day (2024-12-15) has been added to the list!
# Pan American Aviation Day (2024-12-17) has been added to the list!
# Wright Brothers Day (2024-12-17) has been added to the list!
# December Solstice (2024-12-21) has been added to the list!
# Christmas Eve (2024-12-24) has been added to the list!
# Christmas Day (2024-12-25) has been added to the list!
# Kwanzaa (first day) (2024-12-26) has been added to the list!
# New Year's Eve (2024-12-31) has been added to the list!
# 121 holidays have been added for the year 2024.
# 627

# %%
# testing week filtering functionality

# how to properly display filtered by week list
# it's in a list, so you need to print individual object in the list
for i in a.filter_holidays_by_week(2021,2): print(i)
z = a.filter_holidays_by_week(2021,2)
# Out:
# World Sketchnote Day (2021-01-11)
# Zanzibar Revolution Day (2021-01-12)
# National Rubber Ducky Day (2021-01-13)
# Tamil Thai Pongdal Day (2021-01-14)
# National Bagel Day (2021-01-15)
# Signing of the Peace Accords (2021-01-16)
# Stephen Foster Memorial Day (2021-01-13)

# %%
# Testing for saving to JSON file
a = HolidayList()
a.read_json('holidays.json')
z = a.innerHolidays

# converting objects in innerholidays to dictionary format
zDict = list(map(lambda b: b.dictionaryOut(), z))
l = {'holidays':zDict}

text = json.dumps(l, indent=2)

with open("test_holidayoutput.json", "w") as file:
    file.write(text)

# %%
# Testing dictionary conversion in Holiday object for use converting HolidayList to dictionary

dtconvert = datetime.strptime("2021-01-13", '%Y-%m-%d')
ree = Holiday("National Rubber Ducky Day", dtconvert)

ree.dictionaryOut()
# Out:
# {'name': 'National Rubber Ducky Day', 'date': '2021-01-13'}

# %%
# Testing JSON import before putting it in class definitino
# legacy

# importing all holidays from json file
# holidays.json starting location
presetHolidaysLoc = 'holidays.json'

# initializing holidays dictionary
holList = []

# reading in holidays.json
def readHolidaysJson():
    global holidays
    # Read dictionary file in from dictionary file location
    with open(presetHolidaysLoc) as file:
        holidays = json.load(file)['holidays']
    for i in range(0, len(holidays)):
        datetime_object = datetime.strptime(holidays[i]['date'], '%Y-%m-%d')
        print(datetime_object.year, datetime_object.isocalendar()[1])
        a = Holiday(holidays[i]['name'], datetime_object)
        holList.append(a)
        
readHolidaysJson()
# Out:
# 2021 1
# 2021 2
# 2021 2
# 2021 2
# 2021 2
# 2021 2
# 2021 2

# %%
# Testing find holiday functionality
dtconvert = datetime.strptime("2021-01-13", '%Y-%m-%d')
z = holList.findHoliday("National Rubber Ducky Day", dtconvert)
print(z)

# %%
# Testing remove holiday functionality
dtconvert = datetime.strptime("2021-01-13", '%Y-%m-%d')
holList.removeHoliday("National Rubber Ducky Day", dtconvert)
print(holList)

# %%
# Testing for webscraping before putting into member function
# legacy

# main body for extracting (1) name of the holiday, (2) date of the holiday
# main body of content: in <table id"holidays-table"...
def TaDScrape(year):
    global holidayList
    url = "https://www.timeanddate.com/holidays/us/{}?hol=33554809".format(year)
    response = requests.get(url).text
    soup = BeautifulSoup(response,'html.parser')

    # isolate just the holiday table body
    holidayTable = soup.find('table',attrs={'id':'holidays-table'}).find('tbody')

    # get a list of all the specific holidays, taking out the first one because it is not a holiday lol
    perHoliday = holidayTable.find_all('tr', attrs={'class':'showrow'})
    count = 0 # to make sure all the holidays have been counted

    # going through all the holidays and getting the info
    for i in range(0,len(perHoliday)):
        # getting the date, converting to datetime using strings
        dateRaw = perHoliday[i].find('th', attrs={'class':'nw'}).text
        dateString = (f"{dateRaw} {year}")
        dateObject = datetime.strptime(dateString, "%b %d %Y")
        # getting the name
        name = perHoliday[i].find('a').text
        holidayList.append(Holiday(name, dateObject))
        count += 1
        
    print(f"There are {count} holidays on this page for the year {year}.")

# scraping stuff
# get soup output for webpage per url
# combined into the TaDScrape function
def getSOUP(url):
    response = requests.get(url).text
    output = BeautifulSoup(response,'html.parser')
    return output

# dates output in the website as Jan 1, so convert this to json version: YYYY-MM-DD
# combined into the TaDScrape function
def dateConv(dateStr, year):
    dateString = (f"{dateStr} {year}")
    dateObject = datetime.strptime(dateString, "%b %d %Y")
    try:
        return dateObject
    except:
        print("data scraping: check if date formatting is still the same, edit dateConv()")

# %%
# scraping from website, based on year
currentYear = 2022
for year in range(currentYear-2,currentYear+3): TaDScrape(year)
# Out:
# There are 124 holidays on this page for the year 2020.
# There are 127 holidays on this page for the year 2021.
# There are 125 holidays on this page for the year 2022.
# There are 124 holidays on this page for the year 2023.
# There are 121 holidays on this page for the year 2024.

# %%
# Testing for weather API, only forecast data?

# using the 16 day forecast option for rapidAPI
url = "https://community-open-weather-map.p.rapidapi.com/forecast/daily"

querystring = {"q":city,"lat":"35","lon":"139","cnt":"16","units":"metric or imperial"}

headers = {
	"X-RapidAPI-Key": weatherAPIKey,
	"X-RapidAPI-Host": "community-open-weather-map.p.rapidapi.com"
}

weather = requests.request("GET", url, headers=headers, params=querystring).text

# %%
# Testing matching up the raw weather data with dates using only today as the metric

today = datetime.today().replace(hour=0, minute=0, second=0, microsecond=0)

weatherDictRaw = json.loads(weather)["list"]
weatherDictforDisplay = {}
for i in range(0,len(weatherDictRaw)):
    delta = timedelta(days=i)
    day = today+delta
    weatherDictforDisplay[day] = weatherDictRaw[i]['weather'][0]['main']

print(list(weatherDictforDisplay.keys()))

year = 2022
weekNum = 28
weatherDictWeek = {}
for i in range(1,8):
    weekday = datetime.strptime(f'{year} {weekNum} {i}', '%G %V %u')
    if weekday in list(weatherDictforDisplay.keys()):
        weatherDictWeek[weekday] = weatherDictforDisplay[weekday]
    else:
        weatherDictWeek[weekday] = "no data"

print(weatherDictWeek)
# Out:
# [datetime.datetime(2022, 7, 11, 0, 0), datetime.datetime(2022, 7, 12, 0, 0), datetime.datetime(2022, 7, 13, 0, 0), datetime.datetime(2022, 7, 14, 0, 0), datetime.datetime(2022, 7, 15, 0, 0), datetime.datetime(2022, 7, 16, 0, 0), datetime.datetime(2022, 7, 17, 0, 0), datetime.datetime(2022, 7, 18, 0, 0), datetime.datetime(2022, 7, 19, 0, 0), datetime.datetime(2022, 7, 20, 0, 0), datetime.datetime(2022, 7, 21, 0, 0), datetime.datetime(2022, 7, 22, 0, 0), datetime.datetime(2022, 7, 23, 0, 0), datetime.datetime(2022, 7, 24, 0, 0), datetime.datetime(2022, 7, 25, 0, 0), datetime.datetime(2022, 7, 26, 0, 0)]
# {datetime.datetime(2022, 7, 11, 0, 0): 'Clear', datetime.datetime(2022, 7, 12, 0, 0): 'Rain', datetime.datetime(2022, 7, 13, 0, 0): 'Rain', datetime.datetime(2022, 7, 14, 0, 0): 'Rain', datetime.datetime(2022, 7, 15, 0, 0): 'Rain', datetime.datetime(2022, 7, 16, 0, 0): 'Rain', datetime.datetime(2022, 7, 17, 0, 0): 'Rain'}

# %%
# definitions for functions for sample UI check
savedState = False
theList = HolidayList()
newfilelocation = "test_holiday.json"

def StartUp():
    global theList
    theList.read_json('holidays.json')
    theList.scrapeHolidays()
    totalNum = theList.numHolidays()
    print("Holiday Management")
    print("====================")
    print(f"There are {totalNum} holidays stored in the system")

def MainMenu():
    print("====================")
    print("====================")
    print("Holiday Menu")
    print("====================")
    print("1. Add a Holiday")
    print("2. Remove a Holiday")
    print("3. Save Holiday List")
    print("4. View Holidays")
    print("5. Exit")
    while True:
        nextPage = int(input("What would you like to do? Enter the number of the option needed: "))
        if nextPage not in range(1,6):
            print("Wrong input!")
        else:
            if nextPage == 1: AddHoliday()
            elif nextPage == 2: RemoveHoliday()
            elif nextPage == 3: SaveHolidayList()
            elif nextPage == 4: ViewHolidays()
            elif nextPage == 5: 
                exitstatus = Exit()
                if exitstatus == True: break

def AddHoliday():
    print("Add a Holiday")
    print("====================")
    global theList
    global savedState
    newHolidayName = str(input("Holiday: "))
    newHolidayDateRaw = str(input("Date (YYYY-MM-DD): "))
    while True:
        try:
            newHolidayDate = datetime.strptime(newHolidayDateRaw, '%Y-%m-%d')
            break
        except:
            print("Error: \nInvalid date. Please try again.")
            newHolidayDateRaw = str(input(f"Date for {newHolidayName} (YYYY-MM-DD): "))
    newHolidayObject = Holiday(newHolidayName,newHolidayDate)
    theList.addHoliday(newHolidayObject)
    print(f"Success:\n{newHolidayObject} has been added to the holiday list.")
    savedState = False

def RemoveHoliday():
    print("Remove a Holiday")
    print("====================")
    global theList
    global savedState
    while True:
        removeHolidayName = str(input("Holiday Name: "))
        if removeHolidayName == "0": 
            break
        allDates = theList.findHoliday(removeHolidayName,None)
        if len(allDates) != 0:
            for i in allDates:
                theList = theList.removeHoliday(i.name, i.date)
            print(f"Success:\n{removeHolidayName} has been removed from the holiday list.")
            savedState = False
            break
        else:
            print(f"Error: \n{removeHolidayName} not found. Please try again, or enter 0 to exit.")

def SaveHolidayList():
    print("Saving Holiday List")
    print("====================")
    global theList
    global savedState
    global newfilelocation
    while True:
        save = str(input("Are you sure you want to save your changes? [y/n]: "))
        if save == "y":
            theList.save_to_json(newfilelocation)
            savedState = True
            print(f"Success:\nYour changes have been saved.")
            break
        elif save == "n":
            print(f"Canceled:\nHoliday list file save canceled.")
            break
        else: print("Wrong input!")


def ViewHolidays():
    print("View Holidays")
    print("====================")
    global theList
    global currentYear

    #correct year loop
    while True:
        year = int(input("Which year? "))
        if year in range(2010,currentYear+3): break
        else: 
            print("This year is likely not supported, or is in the wrong format.")
            print(f"Please enter a year between 2010 and {currentYear+2}")

    #correct week loop
    while True:
        week = str(input("Which week? #[1-52, Leave blank for the current week]: "))
        if week == "": break
        elif int(week) in range(1,53): break
        else: 
            print("This is not a possible calendar week number within a year, or is in the wrong format.")
            print(f"Please enter a week number between 1 and 52, or leave the input blank.")

    # a week input is not given: run view current week function
    if week == "":
        theList.viewCurrentWeek()
    elif int(week) in range(1,53):
        print(f"These are the holidays for {year} week #{week}:")
        displayList = theList.filter_holidays_by_week(year, int(week))
        theList.displayHolidaysInWeek(displayList)


def Exit():
    global savedState
    print("Exit")
    print("====================")
    while True:
        if savedState:
            exitStatus = str(input("Are you sure you want to exit? [y/n]: "))
        else: 
            exitStatus = str(input("Are you sure you want to exit?\nYour changes will be lost.\n[y/n]: "))
        if exitStatus == "y" or exitStatus == "n":
            break
        print("Wrong input!")
    if exitStatus == "y":
        # end program
        return True

StartUp()
MainMenu()
# Out:
# Holiday Management
# ====================
# There are 627 holidays stored in the system
# ====================
# ====================
# Holiday Menu
# ====================
# 1. Add a Holiday
# 2. Remove a Holiday
# 3. Save Holiday List
# 4. View Holidays
# 5. Exit
# Add a Holiday
# ====================
# Success:
# Hermione (2022-11-07) has been added to the holiday list.
# Exit
# ====================
